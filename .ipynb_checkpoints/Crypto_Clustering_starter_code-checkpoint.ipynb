# %%
# Import required libraries and dependencies
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import hvplot.pandas

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
data = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %% [markdown]
# ### Prepare the Data

# %%
# Reset the index to make 'coin_id' a regular column
data.reset_index(inplace=True)



# Normalize the data using StandardScaler
scaler = StandardScaler()
numeric_columns = data.columns[1:]

# Fit and transform the data
scaled_data = scaler.fit_transform(data[numeric_columns])

# %%
# Create a DataFrame with the scaled data
print(data.columns)
scaled_df = pd.DataFrame(scaled_data, columns=numeric_columns)

# Copy the crypto names from the original data

scaled_df['coin_id'] = data['coin_id']

# Set the coin_id column as index
scaled_df.set_index('coin_id', inplace=True)

# Display sample data
scaled_df.head()
# Out:
# Index(['coin_id', 'price_change_percentage_24h', 'price_change_percentage_7d',
#        'price_change_percentage_14d', 'price_change_percentage_30d',
#        'price_change_percentage_60d', 'price_change_percentage_200d',
#        'price_change_percentage_1y'],
#       dtype='object')
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# ...

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values to try
k_values = range(1, 11)

# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for k in k_values:
    # Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    # Fit the model to the data using the scaled DataFrame
    kmeans.fit(scaled_df)
    # Append the model.inertia_ to the inertia list
    inertia.append(kmeans.inertia_)

# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': k_values, 'inertia': inertia}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)

# Display the DataFrame
print(elbow_df)
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  212.123342
# 2   3  170.193571
# 3   4   79.022435
# 4   5   71.097914
# 5   6   66.108827
# 6   7   54.488123
# 7   8   43.224693
# 8   9   32.860884
# 9  10   28.404885

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.

# Plot the Elbow curve
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.plot(elbow_df['k'], elbow_df['inertia'], marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer:**
# k=4

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k
best_k = 4
kmeans = KMeans(n_clusters=best_k, random_state=42)

# %%
# Fit the K-Means model using the scaled data
kmeans.fit(scaled_df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
clusters = kmeans.predict(scaled_df)

# View the resulting array of cluster values.
print(clusters)
# Out:
# [0 0 2 2 0 0 0 0 0 2 2 2 2 0 2 0 2 2 0 2 2 0 2 2 2 2 2 2 0 2 2 2 3 0 2 2 1
#  2 2 2 2]

# %%
# Create a copy of the DataFrame
clustered_df = scaled_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
clustered_df['Cluster'] = clusters

# Display sample data
clustered_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using Pandas plot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    x=clustered_df['price_change_percentage_24h'],
    y=clustered_df['price_change_percentage_7d'],
    c=clustered_df['Cluster'],
    cmap='rainbow'
)
plt.colorbar(scatter)
plt.xlabel('Price Change Percentage 24h')
plt.ylabel('Price Change Percentage 7d')
plt.title('Cryptocurrency Clusters')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the original scaled DataFrame to reduce to three principal components.
pca_data = pca.fit_transform(scaled_df)
print(pca_data[:5])
# View the first five rows of the DataFrame. 
pca_df = pd.DataFrame(pca_data, columns=['PC1', 'PC2', 'PC3'])
pca_df['Cluster'] = clusters
pca_df.head()
# Out:
# [[-0.60066733  0.84276006  0.46159457]
#  [-0.45826071  0.45846566  0.95287678]
#  [-0.43306981 -0.16812638 -0.64175193]
#  [-0.47183495 -0.22266008 -0.47905316]
#  [-1.15779997  2.04120919  1.85971527]]
#         PC1       PC2       PC3  Cluster
# 0 -0.600667  0.842760  0.461595        0
# 1 -0.458261  0.458466  0.952877        0
# 2 -0.433070 -0.168126 -0.641752        2
# 3 -0.471835 -0.222660 -0.479053        2
# 4 -1.157800  2.041209  1.859715        0

# %%
# Retrieve the explained variance to determine how much information  can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_


print("Explained variance ratio of each principal component:")
for i, var in enumerate(explained_variance, start=1):
    print(f"PC{i}: {var:.4f}")


cumulative_variance = explained_variance.cumsum()
print("Cumulative explained variance ratio:")
for i, cum_var in enumerate(cumulative_variance, start=1):
    print(f"PC{i}: {cum_var:.4f}")

total_explained_variance = explained_variance.sum()
print(f"Total explained variance by the three principal components: {total_explained_variance:.4f}")
# Out:
# Explained variance ratio of each principal component:
# PC1: 0.3720
# PC2: 0.3470
# PC3: 0.1760
# Cumulative explained variance ratio:
# PC1: 0.3720
# PC2: 0.7190
# PC3: 0.8950
# Total explained variance by the three principal components: 0.8950

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** Total explained variance by the three principal components: 0.8950

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you

# Creating a DataFrame with the PCA data
pca_df = pd.DataFrame(pca_data, columns=['PC1', 'PC2', 'PC3'])

# Copy the crypto names from the original data
pca_df['coin_id'] = data['coin_id']

# Set the coinid column as index
pca_df.set_index('coin_id', inplace=True)

# Display sample data
pca_df
# Out:
#                            PC1       PC2       PC3
# coin_id
# bitcoin              -0.600667  0.842760  0.461595
# ethereum             -0.458261  0.458466  0.952877
# tether               -0.433070 -0.168126 -0.641752
# ripple               -0.471835 -0.222660 -0.479053
# bitcoin-cash         -1.157800  2.041209  1.859715
# binancecoin          -0.516534  1.388377  0.804071
# chainlink            -0.450711  0.517699  2.846143
# cardano              -0.345600  0.729439  1.478013
# litecoin             -0.649468  0.432165  0.600303
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653
# crypto-com-chain     -0.248198 -1.376252 -1.462026
# usd-coin             -0.438408 -0.175337 -0.663388
# eos                  -0.693425 -0.473815 -0.527597
# monero                0.060499  2.909404  1.498571
# tron                 -0.393352 -0.108192 -0.012756
# tezos                -0.796176 -0.494409  1.082812
# okb                   0.064075 -1.269825 -1.098829
# ...

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k_values = range(1, 11)
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using PCA DataFrame.
# 3. Append the model.inertia_ to the inertia list

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pca_df)
    inertia.append(kmeans.inertia_)
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': k_values, 'inertia': inertia}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)

# Display the DataFrame
elbow_df
# Out:
#     k     inertia
# 0   1  256.874086
# 1   2  182.339530
# 2   3  140.431833
# 3   4   49.665497
# 4   5   42.051901
# 5   6   31.749005
# 6   7   28.031869
# 7   8   19.451747
# 8   9   13.814082
# 9  10   10.630648

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
plt.figure(figsize=(10, 6))
plt.plot(k_values, inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** K=4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** To determine if the optimal k value differs from that found using the original data, we need to compare this with the elbow curve derived from the original, non-PCA-transformed data. If the original data's elbow curve also indicated 𝑘=4, then there is no difference. However, if the original data suggested a different k, then they differ. Assuming the best k found using the original data is different (let's say it was 𝑘=3, then we can conclude that PCA transformation has impacted the clustering result.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
best_k = 4  # Assuming the best k value found is 4
kmeans = KMeans(n_clusters=best_k)

# %%
# Fit the K-Means model using the PCA data
kmeans.fit(pca_df)
# Out:
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
clusters = kmeans.predict(pca_df)

# Print the resulting array of cluster values.
print(clusters)
# Out:
# [3 3 0 0 3 3 3 3 3 0 0 0 0 3 0 3 0 0 3 0 0 3 0 0 0 0 0 0 3 0 0 0 1 3 0 0 2
#  0 0 0 0]

# %%
# Create a copy of the DataFrame with the PCA data

clustered_pca_df = pca_df.copy()
# Add a new column to the DataFrame with the predicted clusters
clustered_pca_df['crypto_cluster'] = clusters

# Display sample data
clustered_pca_df.head(5)
# Out:
#                    PC1       PC2       PC3  crypto_cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595               3
# ethereum     -0.458261  0.458466  0.952877               3
# tether       -0.433070 -0.168126 -0.641752               0
# ripple       -0.471835 -0.222660 -0.479053               0
# bitcoin-cash -1.157800  2.041209  1.859715               3

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`. 
import hvplot.pandas
scatter_plot = clustered_pca_df.hvplot.scatter(
    x='PC1',
    y='PC2',
    by='crypto_cluster',
    hover_cols=['coin_id']
)
scatter_plot
# Out:
# :NdOverlay   [crypto_cluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index.
pca_components = pd.DataFrame(
    pca.components_,
    columns=numeric_columns,
    index=['PCA1', 'PCA2', 'PCA3']
)

strongest_influences = pca_components.idxmax(axis=1), pca_components.max(axis=1), pca_components.idxmin(axis=1), pca_components.min(axis=1)
strongest_influences
# Out:
# (PCA1    price_change_percentage_200d
#  PCA2     price_change_percentage_30d
#  PCA3      price_change_percentage_7d
#  dtype: object,
#  PCA1    0.594468
#  PCA2    0.562182
#  PCA3    0.787670
#  dtype: float64,
#  PCA1    price_change_percentage_24h
#  PCA2     price_change_percentage_1y
#  PCA3    price_change_percentage_60d
#  dtype: object,
#  PCA1   -0.416728
#  PCA2   -0.150789
#  PCA3   -0.361377
#  dtype: float64)

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:**
# Based on the output, the features with the strongest positive and negative influences on each principal component are:
#
# Strongest Positive Influences:
# PCA1:
# Feature: price_change_percentage_200d
# Influence: 0.594468
#
#
# PCA2:
# Feature: price_change_percentage_30d
# Influence: 0.562182
#
#
# PCA3:
# Feature: price_change_percentage_7d
# Influence: 0.787670
#
#
#
#
# Strongest Negative Influences:
# PCA1:
# Feature: price_change_percentage_24h
# Influence: -0.416728
#
# PCA2:
# Feature: price_change_percentage_1y
# Influence: -0.150789
#
# PCA3:
# Feature: price_change_percentage_60d
# Influence: -0.361377
#
#
# Summary:
# PCA1 is most positively influenced by price_change_percentage_200d and most negatively influenced by price_change_percentage_24h.
# PCA2 is most positively influenced by price_change_percentage_30d and most negatively influenced by price_change_percentage_1y.
# PCA3 is most positively influenced by price_change_percentage_7d and most negatively influenced by price_change_percentage_60d.
